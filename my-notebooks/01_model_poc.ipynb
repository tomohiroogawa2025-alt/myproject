# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib

print(sys.version)
print(sys.executable)
print(pd.__version__)
print(np.__version__)
print(sklearn.__version__)
# Out:
# 3.12.10 (main, May 10 2026, 01:15:35) [Clang 17.0.0 (clang-1700.6.3.2)]
# /Users/ogawatomohiro/myproject/.venv/bin/python
# 3.0.2
# 2.4.4
# 1.8.0
